# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
versuch1 = np.genfromtxt(r"..\Data\20211206_154423_versuch1.csv", skip_header=47, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list1 = np.arange(0, len(versuch1)*60, 60)

# %%
versuch2 = np.genfromtxt(r"..\Data\20211207_145554_versuch2.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list2 = np.arange(0, len(versuch2)*30, 30)

# %%
versuch3 = np.genfromtxt(r"..\Data\20211208_122710_versuch4.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list3 = np.arange(0, len(versuch3)*60, 60)

# %%
versuch4 = np.genfromtxt(r"..\Data\20211208_171608_versuch5.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list4 = np.arange(0, len(versuch4)*5, 5)

# %%
versuch1[40, 3]
# Out:
# 952.0

# %%
fig = plt.figure(figsize=(8, 5), dpi=150)
ax = fig.add_subplot(111)
ax.set_title("CO$_2$-Messung Schlafzimmer (35 - 120 Minuten)")
ax.grid("both")



ax.set_xlabel(r"Zeit in s")
ax.set_ylabel(r"CO$_2$-Konzentration in ppm")

ax.plot(x_list1, versuch1[:, 3], label="Versuch 1")
ax.plot(x_list2, versuch2[:, 3], label="Versuch 2")
ax.plot(x_list3, versuch3[:, 3], label="Versuch 3")
ax.plot(x_list4, versuch4[:, 3], label="Versuch 4")

diff = (versuch1[40, 3] - min(versuch1[:, 3]))*0.05

ax.set_xlim((-120.0, 2520.0))
ax.set_ylim((versuch1[0, 3]-diff, versuch1[40, 3]+diff))

#ax.legend()
fig.tight_layout()
plt.savefig("..\Data\Messungen\CO2_Messung_Schlaf1.png", dpi=200)
plt.show()

# %%
versuch1 = np.genfromtxt(r"..\Data\Messungen\20210107_144717_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list1 = np.arange(0, len(versuch1)*10, 10)

# %%
versuch2 = np.genfromtxt(r"..\Data\Messungen\20210107_160932_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list2 = np.arange(0, len(versuch2)*10, 10)

# %%
versuch3 = np.genfromtxt(r"..\Data\Messungen\20210107_173144_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list3 = np.arange(0, len(versuch3)*10, 10)

# %%
versuch4 = np.genfromtxt(r"..\Data\Messungen\20210108_140032_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list4 = np.arange(0, len(versuch4)*10, 10)

# %%
versuch5 = np.genfromtxt(r"..\Data\Messungen\20210108_150359_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list5 = np.arange(0, len(versuch5)*10, 10)

# %%
fig = plt.figure(figsize=(8, 5), dpi=150)
ax = fig.add_subplot(111)
ax.set_title("CO$_2$-Messung Bad (30 Minuten)")
ax.grid("both")

ax.set_xlabel(r"Zeit in s")
ax.set_ylabel(r"CO$_2$-Konzentration in ppm")

ax.plot(x_list1, versuch1[:, 3], label="Versuch 1")
ax.plot(x_list2, versuch2[:, 3], label="Versuch 2")
ax.plot(x_list3, versuch3[:, 3], label="Versuch 3")
ax.plot(x_list4, versuch4[:, 3], label="Versuch 4")
ax.plot(x_list5, versuch5[:, 3], label="Versuch 5")

#ax.legend()
fig.tight_layout()
plt.savefig("..\Data\Messungen\CO2_Messung_Bad.png", dpi=200)
plt.show()

# %%
versuch6 = np.genfromtxt(r"..\Data\Messungen\20210110_153212_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list6 = np.arange(0, len(versuch6)*10, 10)

# %%
versuch7 = np.genfromtxt(r"..\Data\Messungen\20210110_170115_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list7 = np.arange(0, len(versuch7)*10, 10)

# %%
versuch8 = np.genfromtxt(r"..\Data\Messungen\20210113_145516_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list8 = np.arange(0, len(versuch8)*10, 10)

# %%
versuch9 = np.genfromtxt(r"..\Data\Messungen\20210113_162641_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list9 = np.arange(0, len(versuch9)*10, 10)

# %%
versuchA = np.genfromtxt(r"..\Data\Messungen\20210114_144535_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_listA = np.arange(0, len(versuchA)*10, 10)

# %%
fig = plt.figure(figsize=(8, 5), dpi=150)
ax = fig.add_subplot(111)
ax.set_title("CO$_2$-Messung Schlafzimmer (40 Minuten)")
ax.grid("both")

ax.set_xlabel(r"Zeit in s")
ax.set_ylabel(r"CO$_2$-Konzentration in ppm")

ax.plot(x_list6, versuch6[:, 3], label="Versuch 6")
ax.plot(x_list7, versuch7[:, 3], label="Versuch 7")
ax.plot(x_list8, versuch8[:, 3], label="Versuch 8")
ax.plot(x_list9, versuch9[:, 3], label="Versuch 9")
ax.plot(x_listA, versuchA[:, 3], label="Versuch 10")

# ax.legend()
fig.tight_layout()
plt.savefig("..\Data\Messungen\CO2_Messung_Schlafzimmer.png", dpi=200)
plt.show()

# %%
versuchB = np.genfromtxt(r"..\Data\Messungen\20210120_131444_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_listB = np.arange(0, len(versuchB)*10, 10)

# %%
versuchC = np.genfromtxt(r"..\Data\Messungen\20210120_141226_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_listC = np.arange(0, len(versuchC)*10, 10)

# %%
versuchD= np.genfromtxt(r"..\Data\Messungen\20210120_160004_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_listD = np.arange(0, len(versuchD)*10, 10)

# %%
versuchE = np.genfromtxt(r"..\Data\Messungen\20210120_170349_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_listE = np.arange(0, len(versuchE)*10, 10)

# %%
versuchF = np.genfromtxt(r"..\Data\Messungen\20210121_152657_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_listF = np.arange(0, len(versuchF)*10, 10)

# %%
fig = plt.figure(figsize=(8, 5), dpi=150)
ax = fig.add_subplot(111)
ax.set_title("CO$_2$-Messung Wohnzimmer (40 Minuten)")
ax.grid("both")

ax.set_xlabel(r"Zeit in s")
ax.set_ylabel(r"CO$_2$-Konzentration in ppm")

ax.plot(x_listB, versuchB[:, 3], label="Versuch 11")
ax.plot(x_listC, versuchC[:, 3], label="Versuch 12")
ax.plot(x_listD, versuchD[:, 3], label="Versuch 13")
ax.plot(x_listE, versuchE[:, 3], label="Versuch 14")
ax.plot(x_listF, versuchF[:, 3], label="Versuch 15")

# ax.legend()
fig.tight_layout()
plt.savefig("..\Data\Messungen\CO2_Messung_Wohnzimmer.png", dpi=200)
plt.show()

# %%
versuchHSB = np.genfromtxt(r"..\Data\Messungen\20210111_125337_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_listHSB = np.arange(0, len(versuchHSB)*30, 30)

# %%
fig = plt.figure(figsize=(9, 5), dpi=150)
ax = fig.add_subplot(111)
ax.set_title("CO$_2$-Messung Höhrsaal B")
ax.grid("both")

ax.plot(x_listHSB, versuchHSB[:, 3], label="Messung")

ax.set_xlim(ax.get_xlim())
ax.set_ylim(ax.get_ylim())

ax.plot([17*30, 17*30], ax.get_ylim(), "r:", label="Fenster werden geschlossen")

ax.legend()
plt.savefig("..\Data\Messungen\C02_Messung_HöhrsaalB.png", dpi=200)
plt.show()

# %%
versuch2P1 = np.genfromtxt(r"..\Data\Messungen\20210125_165254_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list2P1 = np.arange(0, len(versuch2P1)*10, 10)

# %%
versuch2P2 = np.genfromtxt(r"..\Data\Messungen\20210125_174246_log.csv", skip_header=46, skip_footer=2, delimiter=",")
# co2 = file[:, 3]
# temp = file[:, 5]
x_list2P2 = np.arange(0, len(versuch2P2)*10, 10)

# %%
fig = plt.figure(figsize=(9, 5), dpi=150)
ax = fig.add_subplot(111)
ax.set_title("CO$_2$-Messung Wohnzimmer mit zwei Personen")
ax.grid("both")

ax.plot(x_list2P1, versuch2P1[:, 3], label="Versuch 1")
ax.plot(x_list2P2, versuch2P2[:, 3], label="Versuch 2")
ax.plot(x_listE, versuchE[:, 3], label="Versuch 14 (1 Person)")


ax.legend()
plt.savefig("..\Data\Messungen\C02_Messung_HöhrsaalB.png", dpi=200)
plt.show()
