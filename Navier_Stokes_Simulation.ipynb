# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import jit, njit
from time import perf_counter as time
from functools import lru_cache, cache
import scipy.optimize
import matplotlib.colors as mcolors
from matplotlib import animation
from IPython import display

# %%
# %matplotlib notebook

# %%
np.seterr(divide="raise", invalid="raise", under="raise")
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
@njit
def next_step(airp1, airp2, velo1, velo2, conc1, conc2, source, d):
    Rs = 287.1
    T = 300
    v = 13.3e-3
    for x in range(1, x_size - 1):
        for y in range(1, y_size - 1):
            for z in range(1, z_size - 1):
                border = (x == 1) + (y == 1) + (z == 1) + (x == x_size-2) + (y == y_size-2) + (z == z_size-2)
                
                diff_airp = 0
                
                diff_airp -= airp1[x, y, z] * 0.5/dx * (velo1[x+1, y, z, 0] - velo1[x-1, y, z, 0] + velo1[x, y+1, z, 1] - velo1[x, y-1, z, 1] + velo1[x, y, z+1, 2] - velo1[x, y, z-1, 2])
                diff_airp -= velo1[x, y, z, 0] * 0.5/dx * (airp1[x+1, y, z] - airp1[x-1, y, z])
                diff_airp -= velo1[x, y, z, 1] * 0.5/dx * (airp1[x, y+1, z] - airp1[x, y-1, z])
                diff_airp -= velo1[x, y, z, 2] + 0.5/dx * (airp1[x, y, z+1] - airp1[x, y, z-1])
                
                airp2[x, y, z] = airp1[x, y, z] + dt * diff_airp
                
                diff_velo = np.zeros(3)
                
#                 diff_velo[0] -= dt * velo1[x, y, z,  0] * diff_airp / airp1[x, y, z]
#                 diff_velo[1] -= dt * velo1[x, y, z,  1] * diff_airp / airp1[x, y, z]
#                 diff_velo[2] -= dt * velo1[x, y, z,  2] * diff_airp / airp1[x, y, z]

                diff_velo[0] -= 0.5/dx * (velo1[x, y, z, 0] * (velo1[x+1, y, z, 0] - velo1[x-1, y, z, 0]) + velo1[x, y, z, 1] * (velo1[x, y+1, z, 0] - velo1[x,  y-1, z, 0]) + velo1[x, y, z, 2] * (velo1[x, y, z+1, 0] - velo1[x, y, z-1, 0]))
                diff_velo[1] -= 0.5/dx * (velo1[x, y, z, 0] * (velo1[x+1, y, z, 1] - velo1[x-1, y, z, 1]) + velo1[x, y, z, 1] * (velo1[x, y+1, z, 1] - velo1[x,  y-1, z, 1]) + velo1[x, y, z, 2] * (velo1[x, y, z+1, 1] - velo1[x, y, z-1, 1]))
                diff_velo[2] -= 0.5/dx * (velo1[x, y, z, 0] * (velo1[x+1, y, z, 2] - velo1[x-1, y, z, 2]) + velo1[x, y, z, 1] * (velo1[x, y+1, z, 2] - velo1[x,  y-1, z, 2]) + velo1[x, y, z, 2] * (velo1[x, y, z+1, 2] - velo1[x, y, z-1, 2]))
                
                diff_velo[0] -= Rs*T * 0.5/dx * (airp1[x+1, y, z] - airp1[x-1, y, z]) / airp1[x, y, z]
                diff_velo[1] -= Rs*T * 0.5/dx * (airp1[x, y+1, z] - airp1[x, y-1, z]) / airp1[x, y, z]
                diff_velo[2] -= Rs*T * 0.5/dx * (airp1[x, y, z+1] - airp1[x, y, z-1]) / airp1[x, y, z]
                
#                 diff_velo[0] -= dt/dx * (airp1[x+1, y, z] - airp1[x, y, z]) / airp1[x, y, z]
#                 diff_velo[1] -= dt/dx * (airp1[x, y+1, z] - airp1[x, y, z]) / airp1[x, y, z]
#                 diff_velo[2] -= dt/dx * (airp1[x, y, z+1] - airp1[x, y, z]) / airp1[x, y, z]
        
                diff_velo[0] += v/dx**2 * (velo1[x+1, y, z, 0] + velo1[x-1, y, z, 0] + velo1[x, y+1, z, 0] + velo1[x, y-1, z, 0] + velo1[x, y, z+1, 0] + velo1[x, y, z-1, 0] - 6*velo1[x,  y, z, 0])
                diff_velo[1] += v/dx**2 * (velo1[x+1, y, z, 1] + velo1[x-1, y, z, 1] + velo1[x, y+1, z, 1] + velo1[x, y-1, z, 1] + velo1[x, y, z+1, 1] + velo1[x, y, z-1, 1] - 6*velo1[x,  y, z, 1])
                diff_velo[2] += v/dx**2 * (velo1[x+1, y, z, 2] + velo1[x-1, y, z, 2] + velo1[x, y+1, z, 2] + velo1[x, y-1, z, 2] + velo1[x, y, z+1, 2] + velo1[x, y, z-1, 2] - 6*velo1[x,  y, z, 2])

#                 diff_velo[2] -= 9.81 #m/s^2
                
                velo2[x, y, z] = velo1[x, y, z] + dt * diff_velo
        
#                 if x == 1 and velo2[x, y, z, 0] < 0:
#                     velo2[x, y, z, 0] = 0
#                 if y == 1 and velo2[x, y, z, 1] < 0:
#                     velo2[x, y, z, 1] = 0
#                 if z == 1 and velo2[x, y, z, 2] < 0:
#                     velo2[x, y, z, 2] = 0
                    
#                 if x == x_size - 2 and velo2[x, y, z, 0] > 0:
#                     velo2[x, y, z, 0] = 0
#                 if y == y_size - 2 and velo2[x, y, z, 1] > 0:
#                     velo2[x, y, z, 1] = 0
#                 if z == z_size - 2 and velo2[x, y, z, 2] > 0:
#                     velo2[x, y, z, 2] = 0
                
                
                
#                 if x == 12 and y == 14 and z == 11:
#                     velo2[x, y, z, 2] = 0.1
                    
#                 conc2[x, y, z] += (d*dt/(dx**2)) * (conc1[x-1, y, z] + conc1[x+1, y, z] + conc1[x, y-1, z] + conc1[x, y+1, z] + conc1[x, y, z-1] + conc1[x, y, z+1] - (6 - border) * conc1[x, y, z])
                
#                 if x == 12 and y == 14 and z == 11:
#                     conc2[x, y, z] += source*dt

# %%
def next_frame(i, ax, airp1, airp2, velo1, velo2, conc1, conc2, source, d):
    global time_passed
#     if(i%100 == 0):
#         print(i//100, time())
    t = (i+1)*dt
    time_passed = t
#     print(f"t = {t} seconds")
    if i%2:
        next_step(airp2, airp1, velo2, velo1, conc2, conc1, source, d)
    
        offset = mcolors.TwoSlopeNorm(vcenter=0.0)
        img = ax.imshow(velo1[:, 10, :, 0].T, cmap="bwr", norm=offset, origin="lower")

#         offset = mcolors.TwoSlopeNorm(vcenter=1.2041)
#         img = ax.imshow(airp1[16, :, :].T, cmap="bwr", norm=offset, origin="lower")

#         text = ax.text(21.5, 20, f"t = {t:.5f} s", backgroundcolor="white")
#         text_max = ax.text(21.5, 15, f"max_v = {np.abs(velo1[16, :, :, 0]).max():.3f} m/s", backgroundcolor="white")
#         cb = fig.colorbar(img, ax=ax)
        
        return img, #text, text_max
    
    else:
        next_step(airp1, airp2, velo1, velo2, conc1, conc2, source, d)
    
        offset = mcolors.TwoSlopeNorm(vcenter=0.0)
        img = ax.imshow(velo2[:, 10, :, 0].T, cmap="bwr", norm=offset, origin="lower")

#         offset = mcolors.TwoSlopeNorm(vcenter=1.2041)
#         img = ax.imshow(airp2[16, :, :].T, cmap="bwr", norm=offset, origin="lower")
        
#         text = ax.text(21.5, 20, f"t = {t:.5f} s", backgroundcolor="white")
#         text_max = ax.text(21.5, 15, f"max_v = {np.abs(velo2[16, :, :, 0]).max():.3f} m/s", backgroundcolor="white")
#         cb = fig.colorbar(img, ax=ax)
        
        return img, #text, text_max

# %% [raw]
# # @jit
# def next_step(airp1, airp2, velo1, velo2, conc1, conc2, source, d):
#     # airp means air density in this situation
#     Rs = 287.1  # spezifische Gaskonstante
#     T = 300     # Raumtemperatur
#     v = 13.3e-6 # kinematische Viskosität
#
# #     diff_velo = np.zeros((x_size, y_size, z_size, 3))
# #     diff_velo[:-1, :, :, 0] = - Rs*T*np.diff(airp1, axis=0)/dx
# #     diff_velo[:, :-1, :, 1] = - Rs*T*np.diff(airp1, axis=1)/dx
# #     diff_velo[:, :, :-1, 2] = - Rs*T*np.diff(airp1, axis=2)/dx
#
# #     plt.imshow(diff_velo[16, :, :, 1])
# #     plt.colorbar()
# #     plt.show()
#
# #     velo2 = velo1 + dt*diff_velo
#
#     for x in range(1, x_size - 1):
#         for y in range(1, y_size - 1):
#             for z in range(1, z_size - 1):
#                 border = (x == 1) + (y == 1) + (z == 1) + (x == x_size-2) + (y == y_size-2) + (z == z_size-2)
#
#                 velo2[x, y, z] = velo1[x, y, z] + (v*dt/(dx**2)) * (velo1[x-1, y, z] + velo1[x+1, y, z] + velo1[x, y-1, z] + velo1[x, y+1, z] + velo1[x, y, z-1] + velo1[x, y, z+1] - (6 - border) * velo1[x, y, z])
#                 velo2[x, y, z, 0] -= dt/dx * (airp1[x, y, z] - airp1[x-1, y, z]) / airp1[x, y, z] #/ Rs / T
#                 velo2[x, y, z, 1] -= dt/dx * (airp1[x, y, z] - airp1[x, y-1, z]) / airp1[x, y, z] #/ Rs / T
#                 velo2[x, y, z, 2] -= dt/dx * (airp1[x, y, z] - airp1[x, y, z-1]) / airp1[x, y, z] #/ Rs / T
#
#                 airp2[x, y, z] = airp1[x, y, z]
#                 airp2[x, y, z] -= dt/dx * (airp1[x+1, y, z] - airp1[x, y, z]) * velo1[x, y, z, 0]
#                 airp2[x, y, z] -= dt/dx * (airp1[x, y+1, z] - airp1[x, y, z]) * velo1[x, y, z, 1]
#                 airp2[x, y, z] -= dt/dx * (airp1[x, y, z+1] - airp1[x, y, z]) * velo1[x, y, z, 2]
#                 airp2[x, y, z] -= dt/dx * airp1[x, y, z] * (velo1[x, y, z, 0] - velo1[x-1, y, z, 0])
#                 airp2[x, y, z] -= dt/dx * airp1[x, y, z] * (velo1[x, y, z, 1] - velo1[x, y-1, z, 1])
#                 airp2[x, y, z] -= dt/dx * airp1[x, y, z] * (velo1[x, y, z, 2] - velo1[x, y, z-1, 2])
#                 airp2[x, y, z] += dt/dx * (airp1[x, y, z] - airp1[x-1, y, z]) * velo1[x-1, y, z, 0]
#                 airp2[x, y, z] += dt/dx * (airp1[x, y, z] - airp1[x, y-1, z]) * velo1[x, y-1, z, 1]
#                 airp2[x, y, z] += dt/dx * (airp1[x, y, z] - airp1[x, y, z-1]) * velo1[x, y, z-1, 2]
#
#     velo2[0, :, :, 0] = 0
#     velo2[-2, :, :, 0] = 0
#
#     velo2[:, 0, :, 1] = 0
#     velo2[:, -2, :, 1] = 0
#
#     velo2[:, :, 0, 2] = 0
#     velo2[:, :, -2, 2] = 0

# %%
# setup ------------------------------------------
x_size = 36 + 2
y_size = 19 + 2
z_size = 25 + 2
dx = 0.1 #m
dt = 0.00001 #s
# time_steps = (int((60*60) // dt / 2) + 1) * 2
time_steps = 50000
print(time_steps)

d = 0.01

source = 400.0 / dx**3 / 60

conc1 = np.zeros((x_size, y_size, z_size))
conc2 = np.zeros((x_size, y_size, z_size))

airp1 = np.ones((x_size, y_size, z_size)) * 1.2041
airp2 = np.ones((x_size, y_size, z_size)) * 1.2041

# airp1[0, :, :] *= 0
# airp1[:, 0, :] *= 0
# airp1[:, :, 0] *= 0
# airp1[-1, :, :] *= 0
# airp1[:, -1, :] *= 0
# airp1[:, :, -1] *= 0

# airp2[0, :, :] *= 0
# airp2[:, 0, :] *= 0
# airp2[:, :, 0] *= 0
# airp2[-1, :, :] *= 0
# airp2[:, -1, :] *= 0
# airp2[:, :, -1] *= 0

velo1 = np.zeros((x_size, y_size, z_size, 3))
velo2 = np.zeros((x_size, y_size, z_size, 3))

sensor = np.zeros((time_steps))
sensor_v = np.zeros((time_steps))

velo1[16, 10, 12, 0] = 0.1
# airp1[16, 10, 12] *= 1.01
# Out:
# 50000

# %%
fig = plt.figure(figsize=(38/5, 27/5),dpi=150)
ax = fig.add_subplot(111)

# ax.text(21, 0, f"dt = {dt}\nGeschwindigkeit an\neinem Ort\n0,1m/s in x-Richtung")

ax.set_title("Geschwindigkeit | x-Komponente")
ax.set_xlabel("x")
ax.set_ylabel("z")

time_passed = 0


anim = animation.FuncAnimation(fig, next_frame, frames=int(183), interval=1, blit=True, fargs=(ax, airp1, airp2, velo1, velo2, conc1, conc2, source, d))

fig.tight_layout()
plt.show()
# print("start converting")
# video = anim.to_html5_video()
# print("finished converting")
# html = display.HTML(video)
# display.display(html)
# plt.close()
# Out:
# <img src="data:image/png;base64,..." width="1140">

# %%
print(f"Time passed: {time_passed}")
print(f"max_v      : {max(velo1[16].max(), velo2[16].max())}")
print(f"min_v      : {max(velo1[16].min(), velo2[16].min())}")
print(f"max_v_x    : {max(velo1[16, :, :, 0].max(), velo2[16, :, :, 0].max())}")
print(f"min_v_x    : {max(velo1[16, :, :, 0].min(), velo2[16, :, :, 0].min())}")
print(f"max_airp   : {max(airp1[16].max(), airp2[16].max())}")
print(f"min_airp   : {min(airp1[16].min(), airp2[16].min())}")
# Out:
# Time passed: 0.0016300000000000002
# max_v      : 0.06266504846128879
# min_v      : -0.00662406389403927
# max_v_x    : 0.06266504846128879
# min_v_x    : -0.00662406389403927
# max_airp   : 1.204100013086716
# min_airp   : 1.2040999923088622

# %%
print(velo1[11, 10, :, 0])
print(velo1[10, 10, :, 0])
# Out:
# [ 0.00000000e+00 -1.79614271e-06  1.23169525e-06  2.69729203e-06
#   7.16854854e-06  3.20986908e-06 -2.83130986e-06 -3.68009664e-06
#   3.58310905e-06  4.43413322e-06  1.79797286e-05 -1.60938166e-06
#   3.58935274e-05  2.33763744e-06  1.76333247e-05 -4.29316506e-06
#   3.60746906e-06  4.06690012e-06 -1.85304123e-06 -2.20468840e-06
#   8.31766672e-06 -2.10154487e-06  8.33981749e-07  8.16364894e-07
#  -2.71693192e-06  4.63557083e-08  0.00000000e+00]
# [ 0.00000000e+00 -2.08545150e-04 -1.55106865e-03 -4.31397781e-04
#   8.05245313e-04  1.07557014e-03  1.13913950e-03 -5.64546249e-04
#  -1.61557547e-03  2.79097364e-05  2.03102881e-03  2.09503815e-04
#  -1.18138010e-03 -2.25813717e-04  1.99456821e-03 -4.77557851e-05
#  -1.62873960e-03  5.68154798e-04  1.16702447e-03 -1.00974123e-03
#   9.30039902e-04  5.49553643e-04 -1.23003043e-03  3.94474475e-04
#  -2.76715821e-04 -3.01881394e-04  0.00000000e+00]

# %% [raw]
# test_ = []
#
# offset = mcolors.TwoSlopeNorm(vcenter=0.0)
# plt.imshow(velo1[16, :, :, 1].T, cmap="bwr", norm=offset, origin="lower")
# plt.colorbar()
# plt.show()
#
# t = time()
# for i in range(time_steps//2):
#     next_step(airp1, airp2, velo1, velo2, conc1, conc2, source, d)
#     test_.append(airp2.sum())
# #     sensor[2*i] = data2[x_size-7, 9, 6]
# #     sensor_v[2*i] = velo2[x_size-7, 9, 6, 2]
#     offset = mcolors.TwoSlopeNorm(vcenter=0.0)
#     plt.imshow(velo2[16, :, :, 1].T, cmap="bwr", norm=offset, origin="lower")
#     plt.colorbar()
#     plt.show()
#
#     next_step(airp2, airp1, velo2, velo1, conc2, conc1, source, d)
#     test_.append(airp1.sum())
# #     sensor[2*i+1] = data1[x_size-7, 9, 6]
# #     sensor_v[2*i+1] = velo1[x_size-7, 9, 6, 2]
#     offset = mcolors.TwoSlopeNorm(vcenter=0.0)
#     plt.imshow(velo1[16, :, :, 1].T, cmap="bwr", norm=offset, origin="lower")
#     plt.colorbar()
#     plt.show()
#
# print(time() - t)
# print(airp1.sum(),  airp2.sum())
